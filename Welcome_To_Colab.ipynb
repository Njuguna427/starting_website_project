# %% [markdown]
# <a href="https://colab.research.google.com/github/Njuguna427/starting_website_project/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
# finding a square root on a number in python programming
import math
square_root=math.sqrt(4)
print(square_root)
# Out:
# 2.0

# %%
#object oriented programming which deals with functions
class bike:
  name="porche"
  gear=8
bikeobj=bike()
print(bikeobj.name)
# Out:
# porche

# %%
#class named employees
class employees:
  name ="mwangi"
  salary=10000000
employeesobj=employees()
print(employeesobj.name)
print(employeesobj.salary)
# Out:
# mwangi
# 10000000

# %%
class employees:
 def __init__(self,age,name):
  self.name=name
  self.age=age
employ1=employees(30, "Alice")

# %%
#this is a function that runs when we create a new dog
class dog:
  def __init__(self, breed,name,age):
    self.breed=breed
    self.name=name
    self.age=age
def bark(self):
    self.woof="woof"
print("woof")
# Out:
# woof

# %%
class car:
  def __init__(self,name,model,color):
    self.name=name
    self.model=model
    self.color=color
  def start(self):
    print("starting engine")
  def stop(self):
    print("stopping engine")
