# %% [markdown]
# <a href="https://colab.research.google.com/github/Njuguna427/starting_website_project/blob/main/function_implementation_for_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#python functions
def greetings():
  print("hello function")
greetings()
# Out:
# hello function

# %%
def myName():
  print("richard")
myName()
# Out:
# richard

# %%
#python arguments
def myName(name):
  print(name)
myName("kamau")
myName("joseph")
# Out:
# kamau
# joseph

# %%
#a code to add numbers in python arguments
def addNumbers(num1, num2):
 sum =num1+num2
 print (sum)
addNumbers(10,20)
# Out:
# 30

# %%
#write a function that find multplication of three numbers
def multiplyAnswer(num1,num2,num3):
  answer= num1*num2*num3
  print (answer)
multiplyAnswer(2,3,4)
# Out:
# 24

# %%
#write a function that finds the square of a number
def square(num1):
  square=num1*num1
  print(square)
square(4)
# Out:
# 16

# %%
#write function that a number is even or odd(option 2)
def evenoroddnumbers(num1):
  if(num1%2==0):
    print("even")
  else:
    print("odd")
evenoroddnumbers(7)
# Out:
# odd

# %%
#write function that a number is even or odd(option 2)passing user input as arguments
def evenoroddnumbers(num1):
  if(num1%2==0):
    print("even")
  else:
    print("odd")
num = int(input("Enter a number: "))
print("The number is", evenoroddnumbers(num))
# Out:
# Enter a number: 8
# even
# The number is None

# %%
# Function to check if a number is even or odd passing arguments
def check_even_odd(number):
    if number % 2 == 0:
        return "Even"
    else:
        return "Odd"

num = int(input("Enter a number: "))
print("The number is", check_even_odd(num))
# Out:
# Enter a number: 7
# The number is Odd

# %%
#implementing return in a python arguments
def addTwoNumers(num1, num2):
  return num1+num2
  addition=addTwoNumers(19,10)
  print(addition)
